# %% [markdown]
# ## Shelter Location Data Scrape

# %% [markdown]
# ### Imports

# %%
import os
import glob
import numpy as np
from bs4 import BeautifulSoup
from lxml import html
import lxml
import re
import time
import pandas as pd
from selenium import webdriver
import requests
import geopandas
import geopandas.tools
from shapely.geometry import Point
import pickle

def find_hrefs_by_regex(bs, reg_exp):
    all_items = bs.find_all("a", href=re.compile(reg_exp))
    return all_items

# %% [markdown]
# ### Scrape website

# %%
# set up browser
chrome_driver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chrome_driver
driver = webdriver.Chrome(chrome_driver)
base_url = 'http://www.shelterlistings.org/city/san_francisco-ca.html'
driver.get(base_url)

# %%
bs = BeautifulSoup(driver.page_source, 'lxml')

# %%
list_of_urls = find_hrefs_by_regex(bs, '/details/')
set_of_urls = set()
for url in list_of_urls:
    set_of_urls.add(url['href'])

# %%
addresses = []

for url in set_of_urls:
    driver.get(url)
    time.sleep(np.random.randint(low=4, high=7))
    driver.find_element_by_xpath('//button[@id="seeaddress"]').click()
    time.sleep(2)
    bs = BeautifulSoup(driver.page_source, 'lxml')
    try:
        address_text = str(bs.find(id='address').text).strip()
        addresses.append(address_text)
    except:
        address_text = None

# %%
driver.quit()

# %% [markdown]
# ### Process Scraped Data

# %%
addresses
# Out:
# ['4651 Mission St',
#  '85 Second Street',
#  '940 Washington Street',
#  '1735 Mission St',
#  '2100 Webster St #100',
#  '201 8th Street',
#  '703 Market Street',
#  '1175 Howard St.',
#  '180 Howard Street',
#  '763 Jerrold Ave',
#  '3543 18th St',
#  '1021 Mission Street',
#  '150 Golden Gate Ave.',
#  '474 Valencia St',
#  '172 6th Street',
#  '260 Golden Gate Avenue',
#  '350 Golden Gate Ave',
#  '899 Guerrero Street',
#  '1175 Howard St.',
#  '49 Powell Street',
#  '489 Clementina Street',
#  '1815 Egbert Avenue',
#  '146 Leavenworth St.',
#  '965 Mission Street',
#  '126 Hyde St',
#  '1663 Mission Street, Suite 225',
#  '125 Gilbert St',
#  '525 5th Street',
#  '201 8th St.',
#  'C/o Marc Gold',
#  '720 Market St Ste 500',
#  '1167 Mission Street, 4th Floor',
#  '938 Valencia St',
#  '890 Hayes Street',
#  '149 - 9th Street',
#  '900 Pennsylvania Ave',
#  '833 Market St',
#  '701 Sutter Street, Suite 2 (administrative Office)',
#  '260 Golden Gate Avenue',
#  '164 6th Street',
#  '2500 18th St',
#  '164 6th Street',
#  '146 Leavenworth Street',
#  '350 Golden Gate Avenue',
#  '100 Masonic Avenue',
#  '333 7th Street',
#  '2150 Post Street',
#  '1631 Hayes Street',
#  '73 Anderson St',
#  '1446 Market St',
#  'Hugo Street',
#  '3543 18th St Ste 4',
#  '870 Market St',
#  '2121 Market St',
#  '1171 Mission St.',
#  '1757 Waller Street',
#  '1167 Mission St Fl 4',
#  '645 Harrison St',
#  '*shelter Address Confidential*',
#  'Coleridge Street',
#  '3230 San Bruno Ave',
#  '1310 Mission St',
#  '870 Market St Ste 1228',
#  '39 Fell Street',
#  '832 Folsom St',
#  '1049 Howard Street',
#  '701 Sutter Street, Suite 2 (adminstrative Office)',
#  '995 Market St Ste 200',
#  '2157 Grove Street',
#  '180 Howard Street',
#  '1656 15th St',
#  '3543 18th St # 4',
#  '870 Market St',
#  '1500 Howard St',
#  '111 Page St.',
#  '995 Market St',
#  '369 Pine St',
#  '1899 Mission Street',
#  '230 Fourth St',
#  '*location Confidential*',
#  '2111 Jennings Street',
#  '1075 Fillmore St',
#  'Po Box 194464',
#  '938 Valencia St',
#  '864 Ellis St.',
#  '215 Taylor Street',
#  '1550 Bryant Street',
#  '730 Baker Street',
#  '463 26th Ave Apt 304',
#  '180 Howard Street',
#  '309 Steiner St Suite B',
#  '220 Dolores St',
#  '1292 Page Street',
#  '5214 Diamond Heights Blvd # 532',
#  '333 Valencia St Ste 400',
#  '369 Pine St Ste 300',
#  '25 Beulah St',
#  '14th Street',
#  'Pmb 631',
#  '1631 Hayes St',
#  '870 Market St Ste 315',
#  '407 9th Street',
#  '1025 Howard St',
#  '1445 Chinook Ct',
#  '1310 Bacon Street',
#  '1175 Howard St.',
#  '701 Sutter Street, Suite 2 (adminstrative Office)',
#  '1326 4th Ave.',
#  '901 Mission St.',
#  '4439 Third St',
#  '1249 Scott Street',
#  '180 Howard Street, Suite 100',
#  '1025 Howard Street',
#  '815 Buena Vista West',
#  '1663 Mission St',
#  '*address Is Confidential*',
#  '399 Fremont Street, 2nd Floor',
#  '1631 Hayes St',
#  '169 Stillman Street',
#  '1142 Sutter Street',
#  '280 Turk St',
#  'P.o. Box 78037',
#  '1060 Howard St',
#  '701 Sutter Street, Suite 2',
#  '474 Valencia St Ste 280',
#  '2301 Mission Street, Suite 301',
#  '1065 Sutter St',
#  '953 Mission St',
#  '2481 Harrison St',
#  '921 Lincoln Way',
#  '180 Howard Street',
#  '120 Page Street',
#  '200 Pine Street',
#  '165 8th Street, 3rd Floor',
#  '100 Pine Street',
#  '1175 Howard St.',
#  '984 Folsom St. 3rd Floor',
#  '1065 Sutter St',
#  '631 Howard Street',
#  '1025 Howard Street',
#  '40 Boardman Pl',
#  '49 Powell Street',
#  '1275 Mission Street',
#  '1001 Polk Street',
#  '536 Central Avenue',
#  '869 Ellis Street',
#  'P O Box 156455',
#  '1338 Sanchez St.',
#  '212 Ashbury Street',
#  '730 Polk St., Fl. 3',
#  '169 Stillman Street',
#  '637 Van Ness Avenue',
#  '848 Folsom',
#  '424 Guerrero St.',
#  '*shelter Address Confidential*',
#  '55 Sadowa St.']

# %%
addresses_set = set(addresses)
address_df = pd.DataFrame(list(addresses_set))

# %%
address_df.columns = ['street']

# %%
address_df.drop([129], inplace=True)

# %%
address_df.drop([0, 123, 17], inplace=True)

# %%
address_df['street_formatted'] = address_df['street'].apply(lambda x: str(x).replace(' ','+')  + ',San+Francisco,+CA')
address_df
# Out:
#                               street  \
# 1                  1249 Scott Street
# 2                  180 Howard Street
# 3                     333 7th Street
# 4                 1815 Egbert Avenue
# 6                1275 Mission Street
# 7                730 Polk St., Fl. 3
# 8                1899 Mission Street
# 9                 100 Masonic Avenue
# 10               1021 Mission Street
# 11                     4439 Third St
# 12                   4651 Mission St
# 13              463 26th Ave Apt 304
# 14            350 Golden Gate Avenue
# 15                    2121 Market St
# 16        701 Sutter Street, Suite 2
# 18                    73 Anderson St
# 19               169 Stillman Street
# 20                   200 Pine Street
# 21                965 Mission Street
# 22   5214 Diamond Heights Blvd # 532
# 23                  85 Second Street
# 24            870 Market St Ste 1228
# 25                     Po Box 194464
# 26                 703 Market Street
# 27            309 Steiner St Suite B
# 28    2301 Mission Street, Suite 301
# 29                     55 Sadowa St.
# 30              2100 Webster St #100
# 31                      3543 18th St
# 32                  1075 Fillmore St
# ..                               ...
# 107                 2481 Harrison St
# 108                   164 6th Street
# 109             900 Pennsylvania Ave
# 110                   953 Mission St
# 111              146 Leavenworth St.
# 112               3230 San Bruno Ave
# 113                 890 Hayes Street
# 114                 1171 Mission St.
# 115         984 Folsom St. 3rd Floor
# 116               1757 Waller Street
# 117     180 Howard Street, Suite 100
# 118                  474 Valencia St
# 119                  645 Harrison St
# 120                   39 Fell Street
# 121                   1060 Howard St
# 122              637 Van Ness Avenue
# 124          333 Valencia St Ste 400
# 125                  1663 Mission St
# 126                  1175 Howard St.
# 127   1167 Mission Street, 4th Floor
# 128                   125 Gilbert St
# 130               1025 Howard Street
# 131             815 Buena Vista West
# 132                 869 Ellis Street
# 133                  938 Valencia St
# 134                 1292 Page Street
# 135                  120 Page Street
# 136                 424 Guerrero St.
# 137                  1735 Mission St
# 138               1049 Howard Street
#
#                                       street_formatted
# 1                  1249+Scott+Street,San+Francisco,+CA
# 2                  180+Howard+Street,San+Francisco,+CA
# 3                     333+7th+Street,San+Francisco,+CA
# 4                 1815+Egbert+Avenue,San+Francisco,+CA
# 6                1275+Mission+Street,San+Francisco,+CA
# 7                730+Polk+St.,+Fl.+3,San+Francisco,+CA
# 8                1899+Mission+Street,San+Francisco,+CA
# 9                 100+Masonic+Avenue,San+Francisco,+CA
# 10               1021+Mission+Street,San+Francisco,+CA
# 11                     4439+Third+St,San+Francisco,+CA
# 12                   4651+Mission+St,San+Francisco,+CA
# 13              463+26th+Ave+Apt+304,San+Francisco,+CA
# 14            350+Golden+Gate+Avenue,San+Francisco,+CA
# 15                    2121+Market+St,San+Francisco,+CA
# 16        701+Sutter+Street,+Suite+2,San+Francisco,+CA
# 18                    73+Anderson+St,San+Francisco,+CA
# 19               169+Stillman+Street,San+Francisco,+CA
# 20                   200+Pine+Street,San+Francisco,+CA
# 21                965+Mission+Street,San+Francisco,+CA
# 22   5214+Diamond+Heights+Blvd+#+532,San+Francisco,+CA
# 23                  85+Second+Street,San+Francisco,+CA
# 24            870+Market+St+Ste+1228,San+Francisco,+CA
# 25                     Po+Box+194464,San+Francisco,+CA
# 26                 703+Market+Street,San+Francisco,+CA
# 27            309+Steiner+St+Suite+B,San+Francisco,+CA
# 28    2301+Mission+Street,+Suite+301,San+Francisco,+CA
# 29                     55+Sadowa+St.,San+Francisco,+CA
# 30              2100+Webster+St+#100,San+Francisco,+CA
# 31                      3543+18th+St,San+Francisco,+CA
# 32                  1075+Fillmore+St,San+Francisco,+CA
# ..                                                 ...
# 107                 2481+Harrison+St,San+Francisco,+CA
# 108                   164+6th+Street,San+Francisco,+CA
# 109             900+Pennsylvania+Ave,San+Francisco,+CA
# 110                   953+Mission+St,San+Francisco,+CA
# 111              146+Leavenworth+St.,San+Francisco,+CA
# 112               3230+San+Bruno+Ave,San+Francisco,+CA
# 113                 890+Hayes+Street,San+Francisco,+CA
# 114                 1171+Mission+St.,San+Francisco,+CA
# 115         984+Folsom+St.+3rd+Floor,San+Francisco,+CA
# 116               1757+Waller+Street,San+Francisco,+CA
# 117     180+Howard+Street,+Suite+100,San+Francisco,+CA
# 118                  474+Valencia+St,San+Francisco,+CA
# 119                  645+Harrison+St,San+Francisco,+CA
# 120                   39+Fell+Street,San+Francisco,+CA
# 121                   1060+Howard+St,San+Francisco,+CA
# 122              637+Van+Ness+Avenue,San+Francisco,+CA
# 124          333+Valencia+St+Ste+400,San+Francisco,+CA
# 125                  1663+Mission+St,San+Francisco,+CA
# 126                  1175+Howard+St.,San+Francisco,+CA
# 127   1167+Mission+Street,+4th+Floor,San+Francisco,+CA
# 128                   125+Gilbert+St,San+Francisco,+CA
# 130               1025+Howard+Street,San+Francisco,+CA
# 131             815+Buena+Vista+West,San+Francisco,+CA
# 132                 869+Ellis+Street,San+Francisco,+CA
# 133                  938+Valencia+St,San+Francisco,+CA
# 134                 1292+Page+Street,San+Francisco,+CA
# 135                  120+Page+Street,San+Francisco,+CA
# 136                 424+Guerrero+St.,San+Francisco,+CA
# 137                  1735+Mission+St,San+Francisco,+CA
# 138               1049+Howard+Street,San+Francisco,+CA
#
# [134 rows x 2 columns]

# %%
def get_lat_lng(input_addr):
    url = 'https://maps.googleapis.com/maps/api/geocode/json?address={}'.format(input_addr)
    r = requests.get(url)
    r_json = r.json()
    try:
        lat = r_json['results'][0]['geometry']['location']['lat']
    except:
        lat = np.nan
    try:
        lng = r_json['results'][0]['geometry']['location']['lng']
    except:
        lng = np.nan
    return Point(lng, lat)

address_df['geometry'] = address_df['street_formatted'].apply(get_lat_lng)

# %%
address_df['geo_text'] = address_df['geometry'].apply(lambda x: str(x))
len(address_df)
# Out:
# 133

# %%
address_df = address_df.drop_duplicates(['geo_text'], keep='first')

# %%
shelter_locations = geopandas.GeoDataFrame(address_df['geometry'], 
                                          geometry='geometry')

# %%
shelter_locations = shelter_locations.drop([20])

# %%
shelter_locations
# Out:
#                                    geometry
# 1            POINT (-122.4375855 37.781571)
# 2           POINT (-122.3933527 37.7910388)
# 3           POINT (-122.4072079 37.7765976)
# 4           POINT (-122.3990467 37.7265131)
# 6           POINT (-122.4141134 37.7764266)
# 7            POINT (-122.419095 37.7838224)
# 8           POINT (-122.4196788 37.7668046)
# 9           POINT (-122.4471199 37.7806658)
# 10           POINT (-122.409086 37.7804935)
# 11          POINT (-122.3894788 37.7373504)
# 12          POINT (-122.4352369 37.7238416)
# 13          POINT (-122.4861258 37.7807711)
# 14          POINT (-122.4163956 37.7817949)
# 15           POINT (-122.4292989 37.766831)
# 16          POINT (-122.4120114 37.7885698)
# 18          POINT (-122.4148682 37.7419552)
# 19          POINT (-122.3977596 37.7804572)
# 21          POINT (-122.4075924 37.7814089)
# 22           POINT (-122.4399535 37.743714)
# 23          POINT (-122.3999401 37.7885126)
# 24           POINT (-122.407624 37.7850854)
# 25          POINT (-122.4194155 37.7749295)
# 26          POINT (-122.4035824 37.7871787)
# 27          POINT (-122.4324636 37.7723059)
# 28            POINT (-122.418806 37.760087)
# 29          POINT (-122.4557956 37.7122162)
# 30          POINT (-122.4321279 37.7905249)
# 31          POINT (-122.4226557 37.7614397)
# 32          POINT (-122.4320356 37.7792535)
# 33          POINT (-122.4231527 37.7569979)
# ..                                      ...
# 101          POINT (-122.461098 37.7638268)
# 102           POINT (-122.450894 37.767325)
# 103          POINT (-122.416147 37.7731554)
# 104  POINT (-122.4442832 37.77472849999999)
# 105          POINT (-122.411194 37.7844404)
# 106         POINT (-122.4031101 37.7745176)
# 107           POINT (-122.412075 37.757783)
# 108         POINT (-122.4077217 37.7800103)
# 109         POINT (-122.3935173 37.7544355)
# 110         POINT (-122.4074101 37.7815594)
# 112         POINT (-122.4011772 37.7211778)
# 113         POINT (-122.4309031 37.7761764)
# 114           POINT (-122.412407 37.777628)
# 115         POINT (-122.4054644 37.7789181)
# 116         POINT (-122.4525675 37.7680548)
# 119         POINT (-122.3957104 37.7833953)
# 120  POINT (-122.4184877 37.77621389999999)
# 121         POINT (-122.4087629 37.7787764)
# 122         POINT (-122.4206493 37.7815725)
# 124   POINT (-122.421785 37.76768879999999)
# 126         POINT (-122.4107046 37.7766109)
# 128         POINT (-122.4020064 37.7731719)
# 131         POINT (-122.4430364 37.7693224)
# 132         POINT (-122.4202279 37.7836804)
# 133         POINT (-122.4214721 37.7578212)
# 134  POINT (-122.4420736 37.77179539999999)
# 135         POINT (-122.4227803 37.7743059)
# 136         POINT (-122.4244959 37.7642968)
# 137         POINT (-122.4197247 37.7695257)
# 138         POINT (-122.4083063 37.7786413)
#
# [115 rows x 1 columns]

# %% [markdown]
# ### Save Data

# %%
pickle.dump(shelter_locations, open('shelter_locations.pkl', 'wb'))
